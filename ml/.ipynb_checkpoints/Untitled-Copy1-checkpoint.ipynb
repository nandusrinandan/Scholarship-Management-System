# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
data=pd.read_csv('DATASET.csv')

# %%
data
# Out:
#      Academic Year  Prob of Scholarship Acceptance  CGPA  Family Income
# 0             2016                            0.80  7.80              0
# 1             2016                            1.00  9.90          10000
# 2             2016                            0.30  5.20          10000
# 3             2016                            0.50  4.50          10000
# 4             2016                            0.20  4.20              0
# ..             ...                             ...   ...            ...
# 194           2016                            0.25  2.87           5200
# 195           2016                            0.15  1.87           5200
# 196           2016                            0.10  2.50           5200
# 197           2016                            0.70  4.50           5200
# 198           2016                            0.80  4.20           5200
#
# [199 rows x 4 columns]

# %%
data.shape
# Out:
# (199, 4)

# %%
plt.figure(figsize=(16,8))
plt.title('Schoalrship Acceptance')
plt.xlabel('CGPA')
plt.ylabel('Probability of Acceptance')
plt.plot(data['CGPA'])
plt.show()

# %%
data=data[['CGPA']]
data.head(10)
# Out:
#    CGPA
# 0   7.8
# 1   9.9
# 2   5.2
# 3   4.5
# 4   4.2
# 5  10.0
# 6   8.8
# 7   8.5
# 8   7.1
# 9   6.2

# %%
future_days = 25
data['Prediction']=data[['CGPA']].shift(-future_days)
data.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    CGPA  Prediction
# 0   7.8         3.4
# 1   9.9         3.1
# 2   5.2         2.5
# 3   4.5         4.5
# 4   4.2         4.2
# 5  10.0         8.8
# 6   8.8        10.0
# 7   8.5         2.5
# 8   7.1         9.9
# 9   6.2         5.2

# %%
x=np.array(data.drop(['Prediction'],1))[:-future_days]
print(x)
# Out:
# [[ 7.8 ]
#  [ 9.9 ]
#  [ 5.2 ]
#  [ 4.5 ]
#  [ 4.2 ]
#  [10.  ]
#  [ 8.8 ]
#  [ 8.5 ]
#  [ 7.1 ]
#  [ 6.2 ]
#  [ 4.3 ]
#  [ 3.2 ]
#  [10.  ]
#  [ 5.6 ]
#  [ 3.9 ]
#  [ 2.7 ]
#  [ 2.1 ]
#  [ 7.8 ]
#  [ 8.1 ]
#  [ 9.8 ]
#  [ 8.7 ]
#  [ 7.5 ]
#  [ 5.6 ]
#  [ 6.7 ]
#  [ 6.5 ]
#  [ 3.4 ]
#  [ 3.1 ]
#  [ 2.5 ]
#  [ 4.5 ]
#  [ 4.2 ]
#  [ 8.8 ]
#  [10.  ]
#  [ 2.5 ]
#  [ 9.9 ]
#  [ 5.2 ]
#  [10.  ]
#  [ 8.8 ]
#  [10.  ]
#  [ 4.5 ]
#  [ 2.3 ]
#  [ 5.5 ]
#  [ 6.2 ]
#  [10.  ]
#  [ 3.2 ]
#  [10.  ]
#  [ 5.6 ]
#  [ 3.9 ]
#  [ 2.7 ]
#  [ 2.1 ]
#  [ 8.9 ]
#  [ 8.1 ]
#  [ 9.8 ]
#  [ 8.7 ]
#  [ 7.5 ]
#  [ 5.6 ]
#  [ 6.7 ]
#  [ 6.5 ]
#  [ 3.4 ]
#  [ 3.1 ]
#  [ 2.5 ]
#  [ 4.5 ]
#  [ 4.2 ]
#  [ 8.8 ]
#  [10.  ]
#  [ 6.5 ]
#  [ 4.5 ]
#  [ 5.2 ]
#  [10.  ]
#  [ 4.2 ]
#  [10.  ]
#  [ 7.8 ]
#  [ 8.5 ]
#  [ 4.6 ]
#  [ 2.7 ]
#  [10.  ]
#  [ 3.2 ]
#  [10.  ]
#  [ 1.5 ]
#  [ 2.5 ]
#  [ 2.7 ]
#  [ 2.1 ]
#  [ 1.  ]
#  [ 8.1 ]
#  [ 9.8 ]
#  [ 8.7 ]
#  [ 7.5 ]
#  [ 5.6 ]
#  [ 6.7 ]
#  [ 6.5 ]
#  [ 3.4 ]
# ...

# %%
#Create the target data set (y) and convert it to a numpy array and get all of the target value except the last 'x' rows/days
y=np.array(data['Prediction'])[:-future_days]
print(y)
# Out:
# [ 3.4   3.1   2.5   4.5   4.2   8.8  10.    2.5   9.9   5.2  10.    8.8
#  10.    4.5   2.3   5.5   6.2  10.    3.2  10.    5.6   3.9   2.7   2.1
#   8.9   8.1   9.8   8.7   7.5   5.6   6.7   6.5   3.4   3.1   2.5   4.5
#   4.2   8.8  10.    6.5   4.5   5.2  10.    4.2  10.    7.8   8.5   4.6
#   2.7  10.    3.2  10.    1.5   2.5   2.7   2.1   1.    8.1   9.8   8.7
#   7.5   5.6   6.7   6.5   3.4   3.1   2.5   4.5  10.    3.5  10.    2.5
#  10.    5.2   8.32  8.8   4.5   7.8   2.3   5.5   6.2  10.    3.2   1.5
#   5.6   3.9   9.99  2.1   8.9   8.1   9.8   8.7   7.5   5.6   6.7   6.5
#   3.4   3.1   2.5   4.5   4.2   8.8  10.    8.8   8.2   7.5   7.1   2.5
#   4.5  10.    8.8   3.2   6.5   4.5   5.2   8.35  2.4   8.34  6.8   5.4
#   4.6   2.7   2.5   3.2  10.    1.5   2.5   8.98 10.    1.    5.6   2.78
#   9.98  7.5   5.6   6.7   6.5   3.4   3.1   2.5   4.5   4.89  3.5   1.2
#   2.5   8.45  5.2   8.32  8.8   4.5   7.8   2.3   5.5   6.2  10.    3.2
# ...

# %%
#Split the data into 75% training and 25% testing
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
#Create the models
#Create the DECISION TREE REGRESSOR MODEL
tree = DecisionTreeRegressor().fit(x_train,y_train)

#Create the LINEAR REGRESSION MODEL
lr= LinearRegression().fit(x_train,y_train)

# %%
#Get the last 'x' rows of the feature data set
x_future = data.drop(['Prediction'],1)[:-future_days]
x_future = x_future.tail(future_days)
x_future=np.array(x_future)
x_future
# Out:
# array([[10.  ],
#        [ 1.5 ],
#        [ 2.5 ],
#        [ 8.98],
#        [10.  ],
#        [ 1.  ],
#        [ 5.6 ],
#        [ 2.78],
#        [ 9.98],
#        [ 7.5 ],
#        [ 5.6 ],
#        [ 6.7 ],
#        [ 6.5 ],
#        [ 3.4 ],
#        [ 3.1 ],
#        [ 2.5 ],
#        [ 4.5 ],
#        [ 4.89],
#        [ 3.5 ],
#        [ 1.2 ],
#        [ 2.5 ],
#        [ 8.45],
#        [ 5.2 ],
#        [ 8.32],
#        [ 8.8 ]])

# %%
tree_prediction = tree.predict(x_future)
print(tree_prediction)
print()
#Show the model linear regression
lr_prediction = lr.predict(x_future)
print(lr_prediction)
# Out:
# [ 6.51764706  6.15        6.22        5.5         6.51764706 10.
#   4.98333333 10.          5.6         3.43333333  4.98333333  4.34
#   5.75        6.75        6.15        6.22        6.88888889  3.5
#   8.335       5.16        6.22        1.87        2.5         3.5
#   6.68      ]
#
# [5.39225726 6.01321308 5.94015946 5.46677196 5.39225726 6.04973989
#  5.71369322 5.91970444 5.39371834 5.57489133 5.71369322 5.63333423
#  5.64794495 5.87441119 5.89632728 5.94015946 5.7940522  5.76556129
#  5.86710583 6.03512917 5.94015946 5.50549038 5.74291467 5.51498735
#  5.47992161]

# %%
predictions=tree_prediction

valid = data[x.shape[0]:]
valid['Predictions']=predictions
plt.figure(figsize=(16,8))
plt.title('Scholarship Acceptance Graph')
plt.xlabel('CGPA')
plt.ylabel('Probability of Acceptance')
plt.plot(data['CGPA']) 
plt.plot(valid[['CGPA','Predictions']])
plt.legend(['Orig','Val','Pred'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#predict
X=([9.9])
X=pd.DataFrame(X)
Y=tree.predict(X)
Y=pd.DataFrame(Y)
df=pd.concat([X,Y], axis=1)
df
# Out:
#      0    0
# 0  9.9  5.6

# %%
x_future = data.drop(['Prediction'],1)[:-future_days]
x_future = x_future.tail(future_days)
x_future=np.array(x_future)
x_future
# Out:
# array([[10.  ],
#        [ 1.5 ],
#        [ 2.5 ],
#        [ 8.98],
#        [10.  ],
#        [ 1.  ],
#        [ 5.6 ],
#        [ 2.78],
#        [ 9.98],
#        [ 7.5 ],
#        [ 5.6 ],
#        [ 6.7 ],
#        [ 6.5 ],
#        [ 3.4 ],
#        [ 3.1 ],
#        [ 2.5 ],
#        [ 4.5 ],
#        [ 4.89],
#        [ 3.5 ],
#        [ 1.2 ],
#        [ 2.5 ],
#        [ 8.45],
#        [ 5.2 ],
#        [ 8.32],
#        [ 8.8 ]])
